# %%
# !pkill -f tensorboard
# %tensorboard --logdir "C:\Users\bulch\AppData\Local\Temp\tb_wine_1uhqktgf"
# Out:
# "pkill" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.
# Reusing TensorBoard on port 6009 (pid 17080), started 0:29:16 ago. (Use '!kill 17080' to kill it.)
#       <iframe id="tensorboard-frame-9fbd33592057c4a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9fbd33592057c4a");
#           const url = new URL("http://localhost");
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
